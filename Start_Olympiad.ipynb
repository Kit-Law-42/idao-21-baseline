# %% [markdown]
# ### Install py-torch-lightning

# %%
# !pip install git+https://github.com/PyTorchLightning/pytorch-lightning
import pytorch_lightning as pl
print(pl.__version__)
# Out:
# ...
#   Cloning https://github.com/PyTorchLightning/pytorch-lightning to /tmp/pip-req-build-lo5fu16r
#   Running command git clone -q https://github.com/PyTorchLightning/pytorch-lightning /tmp/pip-req-build-lo5fu16r
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 112kB 10.7MB/s
# ...
#      |████████████████████████████████| 829kB 17.5MB/s
# ...
#      |████████████████████████████████| 184kB 35.6MB/s
# ...
#      |████████████████████████████████| 276kB 39.0MB/s
# ...
#      |████████████████████████████████| 1.3MB 42.7MB/s
# ...
#      |████████████████████████████████| 143kB 39.4MB/s
# ...
#      |████████████████████████████████| 296kB 41.0MB/s
# ...
#   Created wheel for pytorch-lightning: filename=pytorch_lightning-1.3.0.dev0-cp37-none-any.whl size=776503 sha256=f5606e79fe385d3b4d47a5ab140c14eb92d067f63c4b8e804fb7c803cf546eff
# ...

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !python drive/MyDrive/Colab\ Notebooks/Olympiad2021/train.py
# Out:
# Global seed set to 666
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-03-22 09:07:55.354787: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
#
#   | Name           | Type       | Params
# ----------------------------------------------
# 0 | layer1         | Sequential | 448
# 1 | drop_out       | Dropout    | 0
# 2 | fc1            | Linear     | 1.8 M
# 3 | fc2            | Linear     | 1.0 K
# 4 | fc3            | Linear     | 501
# 5 | stem           | Sequential | 1.8 M
# 6 | classification | Sequential | 1.8 M
# 7 | train_acc      | Accuracy   | 0
# 8 | valid_acc      | Accuracy   | 0
# 9 | test_acc       | Accuracy   | 0
# ----------------------------------------------
# 1.8 M     Trainable params
# 0         Non-trainable params
# 1.8 M     Total params
# 7.210     Total estimated model params size (MB)
# ...

# %%
import configparser
import os
config = configparser.ConfigParser()
filename = "drive/MyDrive/Colab Notebooks/Olympiad2021/config.ini"
if os.path.isfile(filename):
    parser = configparser.ConfigParser()
    parser.read(filename)
    print(parser.sections())
else:
    print("Config file not found")

parser['DATA'] # Config parser cannot access value.
# Out:
# ['DATA', 'TRAINING', 'REPORT']
# <Section: DATA>

# %%
#!pip install scikit-plot
# !python drive/MyDrive/Colab\ Notebooks/Olympiad2021/report.py
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# INFO:root:Loading checkpoint
# INFO:root:Regression model loaded
# INFO:root:Starting regression task
# INFO:root:Test energy variance: 15.739116668701172
# INFO:root:Energy correlation plot saved at: drive/MyDrive/Colab Notebooks/Olympiad2021/results/energy_correlation.png
# INFO:root:===> Length: 10000 10000
# INFO:root:Energy comparison plot saved at: drive/MyDrive/Colab Notebooks/Olympiad2021/results/energy_comparison.png
# INFO:root:tensor([ 6., 20., 10.,  ...,  1., 20.,  1.])
# ...

# %%
# !python drive/MyDrive/Colab\ Notebooks/Olympiad2021/generate_submission.py

# %%
# !python drive/MyDrive/Colab\ Notebooks/Olympiad2021/generate_submission.py
